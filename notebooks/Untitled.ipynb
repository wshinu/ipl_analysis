# %% [markdown]
# # DATA EXPLORATION AND DATA CLEANING

# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\Dell\\iron hack\\Week_5\\ipl_analysis\\notebooks'

# %%
df = pd.read_csv('C:\\Users\\Dell\\iron hack\\Week_5\\ipl_analysis\\data\\IPL_Ball_by_Ball_2008_2022.csv')

# %%
results = pd.read_csv('C:\\Users\\Dell\\iron hack\\Week_5\\ipl_analysis\\data\\IPL_Matches_2008_2022.csv')

# %%
df
# Out:
#              ID  innings  overs  ballnumber       batter          bowler
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami  \
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run
# ...

# %%
results.head()
# Out:
#         ID       City        Date Season  MatchNumber
# 0  1312200  Ahmedabad  2022-05-29   2022        Final  \
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2
# 0             Rajasthan Royals        Gujarat Titans  \
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  \
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
results['Team1'].nunique()
# Out:
# 18

# %%
results['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
#cols_to_replace = ['Team1', 'Team2', 'Winning Team']
results = results.replace({'Team1': {'Deccan Chargers': 'Sunrisers Hyderabad', 'Delhi Daredevils': 'Delhi Capitals','Gujarat Lions':'Gujarat Titans','Kings XI Punjab':'Punjab Kings','Rising Pune Supergiant':'Rising Pune Supergiants','Pune Warriors':'Rising Pune Supergiants'},'Team2': {'Deccan Chargers': 'Sunrisers Hyderabad', 'Delhi Daredevils': 'Delhi Capitals','Gujarat Lions':'Gujarat Titans','Kings XI Punjab':'Punjab Kings','Rising Pune Supergiant':'Rising Pune Supergiants','Pune Warriors':'Rising Pune Supergiants'},'WinningTeam':{'Deccan Chargers': 'Sunrisers Hyderabad', 'Delhi Daredevils': 'Delhi Capitals','Gujarat Lions':'Gujarat Titans','Kings XI Punjab':'Punjab Kings','Rising Pune Supergiant':'Rising Pune Supergiants','Pune Warriors':'Rising Pune Supergiants'}})

# %%
results['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Rising Pune Supergiants',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
results['Team1'].nunique()
# Out:
# 12

# %%
results
# Out:
#           ID        City        Date   Season  MatchNumber
# 0    1312200   Ahmedabad  2022-05-29     2022        Final  \
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2
# 0               Rajasthan Royals               Gujarat Titans  \
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df["BattingTeam"].nunique()
# Out:
# 18

# %%
df = df.replace({'BattingTeam': {'Deccan Chargers': 'Sunrisers Hyderabad', 'Delhi Daredevils': 'Delhi Capitals','Gujarat Lions':'Gujarat Titans','Kings XI Punjab':'Punjab Kings','Rising Pune Supergiant':'Rising Pune Supergiants','Pune Warriors':'Rising Pune Supergiants'}})

# %%
df["BattingTeam"].nunique()
# Out:
# 12

# %%
results['WinningTeam'].nunique()
# Out:
# 12

# %%
win_counts = results['WinningTeam'].value_counts()

# %%
win_counts
# Out:
# WinningTeam
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Sunrisers Hyderabad            104
# Delhi Capitals                 103
# Punjab Kings                   101
# Rajasthan Royals                96
# Rising Pune Supergiants         27
# Gujarat Titans                  25
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Name: count, dtype: int64

# %%
# define a function to count matches played by a team
def count_matches(team_name, df):
    # select all rows where the 'team1' or 'team2' column contains the team name
    team_matches = results[(results['Team1'] == team_name) | (results['Team2'] == team_name)]

    # count the number of rows in the resulting DataFrame to get the number of matches played by the team
    num_matches = team_matches.shape[0]

    # return the result
    return num_matches

# test the function for each team
teams = ['Rajasthan Royals', 'Royal Challengers Bangalore',
       'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
       'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
       'Punjab Kings', 'Mumbai Indians', 'Rising Pune Supergiants',
       'Kochi Tuskers Kerala']
for team in teams:
    num_matches = count_matches(team, results)
    print('Number of matches played by', team, ':', num_matches)
# Out:
# Number of matches played by Rajasthan Royals : 192
# Number of matches played by Royal Challengers Bangalore : 226
# Number of matches played by Sunrisers Hyderabad : 227
# Number of matches played by Delhi Capitals : 224
# Number of matches played by Chennai Super Kings : 208
# Number of matches played by Gujarat Titans : 46
# Number of matches played by Lucknow Super Giants : 15
# Number of matches played by Kolkata Knight Riders : 223
# Number of matches played by Punjab Kings : 218
# Number of matches played by Mumbai Indians : 231
# Number of matches played by Rising Pune Supergiants : 76
# Number of matches played by Kochi Tuskers Kerala : 14

# %%
# define a function to calculate win percentage for a team
def win_percentage(team_name, df):
    # select all rows where the winner column contains the team name
    wins = results[results['WinningTeam'] == team_name]

    # count the number of rows in the resulting DataFrame to get the number of matches won by the team
    num_wins = wins.shape[0]

    # count the total number of matches played by the team
    matches_played = results[(results['Team1'] == team_name) | (results['Team2'] == team_name)].shape[0]

    # calculate the win percentage
    win_percentage = (num_wins / matches_played) * 100

    # return the result
    return win_percentage

# get a list of all unique team names in the dataset
team_names = results['Team1'].unique()

# create a dictionary to store the win percentage for each team
win_percentages = {}

# calculate the win percentage for each team and store in the dictionary
for team in team_names:
    percentage = win_percentage(team, df)
    win_percentages[team] = percentage

# print the win percentage for each team
for team, percentage in win_percentages.items():
    print('Win percentage for', team, ':', round(percentage, 2), '%')
# Out:
# Win percentage for Rajasthan Royals : 50.0 %
# Win percentage for Royal Challengers Bangalore : 48.23 %
# Win percentage for Sunrisers Hyderabad : 45.81 %
# Win percentage for Delhi Capitals : 45.98 %
# Win percentage for Chennai Super Kings : 58.17 %
# Win percentage for Gujarat Titans : 54.35 %
# Win percentage for Lucknow Super Giants : 60.0 %
# Win percentage for Kolkata Knight Riders : 51.12 %
# Win percentage for Punjab Kings : 46.33 %
# Win percentage for Mumbai Indians : 56.71 %
# Win percentage for Rising Pune Supergiants : 35.53 %
# Win percentage for Kochi Tuskers Kerala : 42.86 %

# %%
# filter the DataFrame to only include final matches
finals_df = results[results['MatchNumber'] == 'Final']

# count the number of times each team appears in the 'winner' column
finals_win_counts = finals_df['WinningTeam'].value_counts()

# get the name of the team that won the most final matches
most_final_wins = finals_win_counts.index[0]

# print the result
print('The team that won the most final matches is:', most_final_wins)
# Out:
# The team that won the most final matches is: Mumbai Indians

# %%
# filter the DataFrame to only include final matches

# count the number of final matches
num_finals = len(finals_df)

# count the number of times each team won a final match
finals_win_counts = finals_df['WinningTeam'].value_counts()

# print the results
print('Total number of final matches:', num_finals)
print('Final wins by team:')
print(finals_win_counts)
# Out:
# Total number of final matches: 15
# Final wins by team:
# WinningTeam
# Mumbai Indians           5
# Chennai Super Kings      4
# Sunrisers Hyderabad      2
# Kolkata Knight Riders    2
# Gujarat Titans           1
# Rajasthan Royals         1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
# group the data by batter, and sum up the batsman_run for each batter
batter_runs = df.groupby('batter')['batsman_run'].sum()

# find the batter with the highest total batsman_run
max_runs_batter = batter_runs.idxmax()
max_runs = batter_runs[max_runs_batter]

# print the results
print('Batter with the most runs:', max_runs_batter)
print('Total runs scored by the batter:', max_runs)
# Out:
# Batter with the most runs: V Kohli
# Total runs scored by the batter: 6634

# %%
df['kind'].unique()
# Out:
# array([nan, 'caught', 'caught and bowled', 'run out', 'bowled', 'stumped',
#        'lbw', 'hit wicket', 'retired hurt', 'retired out',
#        'obstructing the field'], dtype=object)

# %%
df
# Out:
#              ID  innings  overs  ballnumber       batter          bowler
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami  \
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run
# ...

# %%
# filter the data to only include wicket deliveries with specific types of dismissal
wicket_deliveries = df[df['isWicketDelivery'] == 1]
wicket_deliveries = wicket_deliveries[wicket_deliveries['kind'].isin(['caught', 'caught and bowled', 'bowled', 'stumped', 'lbw', 'hit wicket'])]

# group the data by bowler and count the number of rows for each bowler
wicket_counts = wicket_deliveries.groupby('bowler').size()

# find the bowler with the highest wicket count
max_wickets_bowler = wicket_counts.idxmax()
max_wickets = wicket_counts[max_wickets_bowler]

# print the results
print('Bowler with the most wickets:', max_wickets_bowler)
print('Total wickets taken by the bowler:', max_wickets)
# Out:
# Bowler with the most wickets: DJ Bravo
# Total wickets taken by the bowler: 183

# %%
# group the data by batter and calculate the average runs
avg_runs = df.groupby('batter')['batsman_run'].mean()

# sort the data by the average runs and select the top batter
best_avg_batter = avg_runs.sort_values(ascending=False).index[0]
best_avg = avg_runs[best_avg_batter]

# print the results
print('Batter with the best average:', best_avg_batter)
print('Average runs scored by the batter:', best_avg)
# Out:
# Batter with the best average: PN Mankad
# Average runs scored by the batter: 4.0

# %%
# create a new DataFrame with player names and match IDs
players = pd.DataFrame({
    'player': pd.concat([results['Team1Players'].str.split(', '), results['Team2Players'].str.split(', ')]).explode(),
    'match_id': results['ID'].repeat(22)
})

# group the data by player name and count the number of matches played
matches_played = players.groupby('player')['match_id'].nunique()

# sort the data by the number of matches played and select the player with the highest count
most_matches_player = matches_played.sort_values(ascending=False).index[0]
most_matches = matches_played[most_matches_player]

# print the results
print('Player who played the most matches:', most_matches_player)
print('Number of matches played:', most_matches)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 2
#       1 # create a new DataFrame with player names and match IDs
# ----> 2 players = pd.DataFrame({
#       3     'player': pd.concat([results['Team1Players'].str.split(', '), results['Team2Players'].str.split(', ')]).explode(),
#       4     'match_id': results['ID'].repeat(22)
#       5 })
#       7 # group the data by player name and count the number of matches played
#       8 matches_played = players.groupby('player')['match_id'].nunique()
#
# File ~\iron hack\Week_5\ipl_analysis\myenv\lib\site-packages\pandas\core\frame.py:708, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     702     mgr = self._init_mgr(
#     703         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     704     )
#     706 elif isinstance(data, dict):
# ...

# %%
# Create a new DataFrame that stacks the 'Team1' and 'Team2' columns
player_counts = pd.DataFrame({
    'player_name': pd.concat([results['Team1Players'], results['Team2Players']]).values
})

# Count the number of occurrences of each player's name
player_counts = player_counts['player_name'].value_counts()

# Find the player who played the most matches
most_matches_player = player_counts.index[0]

print(f"The player who played the most matches is {most_matches_player}, with {player_counts[0]} matches played.")
# Out:
# The player who played the most matches is ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'AS Joseph', 'Yash Dayal', 'Mohammed Shami'], with 3 matches played.

# %% [markdown]
# # DATA EXPLORATION AND DATA CLEANING

# %%
# importing the libarries
import pandas as pd 
import numpy as np

# %%
#reading csv files 
df = pd.read_csv('C:\\Users\\Dell\\iron hack\\Week_5\\ipl_analysis\\data\\IPL_Matches_2008_2022.csv')

# %%
balls = pd.read_csv('C:\\Users\\Dell\\iron hack\\Week_5\\ipl_analysis\\data\\IPL_Ball_by_Ball_2008_2022.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
balls.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami  \
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary
# 0   JC Buttler        NaN            0           0          0             0  \
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
df.head()
# Out:
#         ID       City        Date Season  MatchNumber
# 0  1312200  Ahmedabad  2022-05-29   2022        Final  \
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2
# 0             Rajasthan Royals        Gujarat Titans  \
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  \
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
balls.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df =df.sort_values(by=['ID'])

# %%
df
# Out:
#           ID        City        Date   Season  MatchNumber
# 949   335982   Bangalore  2008-04-18  2007/08            1  \
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 947   335984       Delhi  2008-04-19  2007/08            3
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 945   335986     Kolkata  2008-04-20  2007/08            4
# ..       ...         ...         ...      ...          ...
# 4    1304116      Mumbai  2022-05-22     2022           70
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
#
#                            Team1                        Team2
# 949  Royal Challengers Bangalore        Kolkata Knight Riders  \
# 948              Kings XI Punjab          Chennai Super Kings
# 947             Delhi Daredevils             Rajasthan Royals
# ...

# %%
balls = balls.sort_values(by=['ID'])

# %%
balls
# Out:
#              ID  innings  overs  ballnumber       batter          bowler
# 225953   335982        2     15           2     SB Joshi       LR Shukla  \
# 225809   335982        1     12           7  BB McCullum       JH Kallis
# 225808   335982        1     12           6  BB McCullum       JH Kallis
# 225807   335982        1     12           5  BB McCullum       JH Kallis
# 225806   335982        1     12           4  BB McCullum       JH Kallis
# ...         ...      ...    ...         ...          ...             ...
# 149     1312200        2      4           5    HH Pandya        TA Boult
# 148     1312200        2      4           4    HH Pandya        TA Boult
# 147     1312200        2      4           3      MS Wade        TA Boult
# 159     1312200        2      6           1    HH Pandya        OC McCoy
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
#
#          non-striker extra_type  batsman_run  extras_run  total_run
# ...

# %% [markdown]
# ### merging both the csv files

# %%
ipl = df.merge(balls, on = 'ID')
ipl.head()
# Out:
#        ID       City        Date   Season MatchNumber
# 0  335982  Bangalore  2008-04-18  2007/08           1  \
# 1  335982  Bangalore  2008-04-18  2007/08           1
# 2  335982  Bangalore  2008-04-18  2007/08           1
# 3  335982  Bangalore  2008-04-18  2007/08           1
# 4  335982  Bangalore  2008-04-18  2007/08           1
#
#                          Team1                  Team2                  Venue
# 0  Royal Challengers Bangalore  Kolkata Knight Riders  M Chinnaswamy Stadium  \
# 1  Royal Challengers Bangalore  Kolkata Knight Riders  M Chinnaswamy Stadium
# 2  Royal Challengers Bangalore  Kolkata Knight Riders  M Chinnaswamy Stadium
# 3  Royal Challengers Bangalore  Kolkata Knight Riders  M Chinnaswamy Stadium
# 4  Royal Challengers Bangalore  Kolkata Knight Riders  M Chinnaswamy Stadium
#
#                     TossWinner TossDecision SuperOver            WinningTeam
# 0  Royal Challengers Bangalore        field         N  Kolkata Knight Riders  \
# ...

# %%
ipl.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2', 'innings', 'overs', 'ballnumber',
#        'batter', 'bowler', 'non-striker', 'extra_type', 'batsman_run',
#        'extras_run', 'total_run', 'non_boundary', 'isWicketDelivery',
#        'player_out', 'kind', 'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
# converting all the column names into lower case
ipl.columns = ipl.columns.str.lower()
ipl.columns
# Out:
# Index(['id', 'city', 'date', 'season', 'matchnumber', 'team1', 'team2',
#        'venue', 'tosswinner', 'tossdecision', 'superover', 'winningteam',
#        'wonby', 'margin', 'method', 'player_of_match', 'team1players',
#        'team2players', 'umpire1', 'umpire2', 'innings', 'overs', 'ballnumber',
#        'batter', 'bowler', 'non-striker', 'extra_type', 'batsman_run',
#        'extras_run', 'total_run', 'non_boundary', 'iswicketdelivery',
#        'player_out', 'kind', 'fielders_involved', 'battingteam'],
#       dtype='object')

# %% [markdown]
# ### cleaning the data

# %%
ipl['venue'].unique()
# Out:
# array(['M Chinnaswamy Stadium',
#        'Punjab Cricket Association Stadium, Mohali', 'Feroz Shah Kotla',
#        'Wankhede Stadium', 'Eden Gardens', 'Sawai Mansingh Stadium',
#        'Rajiv Gandhi International Stadium, Uppal',
#        'MA Chidambaram Stadium, Chepauk', 'Dr DY Patil Sports Academy',
#        'Newlands', "St George's Park", 'Kingsmead', 'SuperSport Park',
#        'Buffalo Park', 'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera', 'Barabati Stadium',
#        'Brabourne Stadium, Mumbai',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
#        'Holkar Cricket Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Subrata Roy Sahara Stadium',
#        'Maharashtra Cricket Association Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
# ...

# %%
ipl['venue'] = ipl['venue'].str.replace('Arun Jaitley Stadium, Delhi','Arun Jaitley Stadium')
ipl['venue'] = ipl['venue'].str.replace('Brabourne Stadium, Mumbai','Brabourne Stadium')
ipl['venue'] = ipl['venue'].str.replace('Eden Gardens, Kolkata','Eden Gardens')
ipl['venue'] = ipl['venue'].str.replace('M Chinnaswamy Stadium','M.Chinnaswamy Stadium')
ipl['venue'] = ipl['venue'].str.replace('MA Chidambaram Stadium, Chepauk, Chennai','MA Chidambaram Stadium')
ipl['venue'] = ipl['venue'].str.replace('MA Chidambaram Stadium, Chepauk','MA Chidambaram Stadium')
ipl['venue'] = ipl['venue'].str.replace('Maharashtra Cricket Association Stadium, Pune','Maharashtra Cricket Association Stadium')
ipl['venue'] = ipl['venue'].str.replace('Punjab Cricket Association IS Bindra Stadium, Mohali','Punjab Cricket Association IS Bindra Stadium')
ipl['venue'] = ipl['venue'].str.replace('Punjab Cricket Association Stadium, Mohali','Punjab Cricket Association IS Bindra Stadium')
ipl['venue'] = ipl['venue'].str.replace('Wankhede Stadium, Mumbai','Wankhede Stadium')
ipl['venue'] = ipl['venue'].str.replace('Rajiv Gandhi International Stadium, Uppal','Rajiv Gandhi International Stadium')
ipl['venue'] = ipl['venue'].str.replace('Feroz Shah Kotla','Arun Jaitley Stadium')
ipl['venue'] = ipl['venue'].str.replace('Sardar Patel Stadium, Motera','Narendra Modi Stadium, Ahmedabad')
ipl['venue'] = ipl['venue'].str.replace('Subrata Roy Sahara Stadium','Maharashtra Cricket Association Stadium')
ipl['venue'] = ipl['venue'].str.replace('Sheikh Zayed Stadium','Zayed Cricket Stadium')
ipl['venue'] = ipl['venue'].str.replace('Zayed Cricket Stadium, Abu Dhabi','Zayed Cricket Stadium')
ipl['venue'] = ipl['venue'].str.replace('Dr DY Patil Sports Academy, Mumbai','Dr DY Patil Sports Academy')

# %%
ipl['venue'].unique()
# Out:
# array(['M.Chinnaswamy Stadium',
#        'Punjab Cricket Association IS Bindra Stadium',
#        'Arun Jaitley Stadium', 'Wankhede Stadium', 'Eden Gardens',
#        'Sawai Mansingh Stadium', 'Rajiv Gandhi International Stadium',
#        'MA Chidambaram Stadium', 'Dr DY Patil Sports Academy', 'Newlands',
#        "St George's Park", 'Kingsmead', 'SuperSport Park', 'Buffalo Park',
#        'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Narendra Modi Stadium, Ahmedabad', 'Barabati Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
#        'Holkar Cricket Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Maharashtra Cricket Association Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'JSCA International Stadium Complex', 'Zayed Cricket Stadium',
# ...

# %%
ipl['season'].unique()
# Out:
# array(['2007/08', '2009', '2009/10', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020/21', '2021', '2022'],
#       dtype=object)

# %%
ipl.season = ipl.season.replace(to_replace='2007/08', value='2008')
ipl.season = ipl.season.replace(to_replace='2009/10', value='2010')
ipl.season = ipl.season.replace(to_replace='2020/21', value='2020')

# %%
ipl['season'].unique()
# Out:
# array(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype=object)

# %%
ipl['city'].isna().any()
# Out:
# True

# %%
ipl.city.fillna(ipl.venue, inplace=True)
ipl.city.unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', 'Sharjah Cricket Stadium',
#        'Dubai International Cricket Stadium', 'Rajkot', 'Kanpur',
#        'Bengaluru', 'Sharjah', 'Dubai', 'Navi Mumbai'], dtype=object)

# %%
ipl['city'] = ipl['city'].str.replace('Dubai International Cricket Stadium','Dubai')
ipl['city'] = ipl['city'].str.replace('Sharjah Cricket Stadium','Sharjah')
ipl['city'] = ipl['city'].str.replace('Navi Mumbai','Mumbai')
ipl['city'] = ipl['city'].str.replace('Bangalore','Bengaluru')

# %%
ipl['city'].unique()
# Out:
# array(['Bengaluru', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', 'Sharjah', 'Dubai', 'Rajkot', 'Kanpur'], dtype=object)

# %%
ipl['city'].isna().any()
# Out:
# False

# %%
ipl
# Out:
#              id       city        date season matchnumber
# 0        335982  Bengaluru  2008-04-18   2008           1  \
# 1        335982  Bengaluru  2008-04-18   2008           1
# 2        335982  Bengaluru  2008-04-18   2008           1
# 3        335982  Bengaluru  2008-04-18   2008           1
# 4        335982  Bengaluru  2008-04-18   2008           1
# ...         ...        ...         ...    ...         ...
# 225949  1312200  Ahmedabad  2022-05-29   2022       Final
# 225950  1312200  Ahmedabad  2022-05-29   2022       Final
# 225951  1312200  Ahmedabad  2022-05-29   2022       Final
# 225952  1312200  Ahmedabad  2022-05-29   2022       Final
# 225953  1312200  Ahmedabad  2022-05-29   2022       Final
#
#                               team1                  team2
# 0       Royal Challengers Bangalore  Kolkata Knight Riders  \
# 1       Royal Challengers Bangalore  Kolkata Knight Riders
# 2       Royal Challengers Bangalore  Kolkata Knight Riders
# ...

# %%
ipl = ipl.replace({'team1': {'Deccan Chargers': 'Sunrisers Hyderabad', 'Delhi Daredevils': 'Delhi Capitals','Gujarat Lions':'Gujarat Titans','Kings XI Punjab':'Punjab Kings','Rising Pune Supergiant':'Rising Pune Supergiants','Pune Warriors':'Rising Pune Supergiants'},'team2': {'Deccan Chargers': 'Sunrisers Hyderabad', 'Delhi Daredevils': 'Delhi Capitals','Gujarat Lions':'Gujarat Titans','Kings XI Punjab':'Punjab Kings','Rising Pune Supergiant':'Rising Pune Supergiants','Pune Warriors':'Rising Pune Supergiants'},'winningteam':{'Deccan Chargers': 'Sunrisers Hyderabad', 'Delhi Daredevils': 'Delhi Capitals','Gujarat Lions':'Gujarat Titans','Kings XI Punjab':'Punjab Kings','Rising Pune Supergiant':'Rising Pune Supergiants','Pune Warriors':'Rising Pune Supergiants'},'tosswinner':{'Deccan Chargers': 'Sunrisers Hyderabad', 'Delhi Daredevils': 'Delhi Capitals','Gujarat Lions':'Gujarat Titans','Kings XI Punjab':'Punjab Kings','Rising Pune Supergiant':'Rising Pune Supergiants','Pune Warriors':'Rising Pune Supergiants'},'battingteam':{'Deccan Chargers': 'Sunrisers Hyderabad', 'Delhi Daredevils': 'Delhi Capitals','Gujarat Lions':'Gujarat Titans','Kings XI Punjab':'Punjab Kings','Rising Pune Supergiant':'Rising Pune Supergiants','Pune Warriors':'Rising Pune Supergiants'}})

# %%
ipl['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Punjab Kings', 'Delhi Capitals',
#        'Mumbai Indians', 'Kolkata Knight Riders', 'Rajasthan Royals',
#        'Sunrisers Hyderabad', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants',
#        'Gujarat Titans', 'Lucknow Super Giants'], dtype=object)

# %%
#importing further libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# analyzing the data with visuals
plt.figure(figsize=(10,8))
data = ipl.groupby(['id','season']).count().index.droplevel(level=0).value_counts().sort_index()
sns.barplot(x=data, y=data.index, orient='h')
plt.xlabel('Matches Played')
plt.ylabel('Season')
plt.show()

# %%
data
# Out:
# season
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# 2017    59
# 2018    60
# 2019    60
# 2020    60
# 2021    60
# 2022    74
# Name: count, dtype: int64

# %%
p = ipl.groupby(['venue','id']).count().droplevel(level=1).index.value_counts()
print('Number of matches played at IPL Venues \n')
print(p)

# Plotting
plt.figure(figsize=(10,8))
data1 = ipl.groupby(['venue','id']).count().droplevel(level=1).index.value_counts().sort_index()
sns.barplot(y=data1.index,x=data1,orient='h')
plt.xlabel('Matches Played')
plt.ylabel('Venue')
plt.title('Number of matches played at IPL Venues')
plt.show()
# Out:
# Number of matches played at IPL Venues
#
# venue
# Wankhede Stadium                                       104
# M.Chinnaswamy Stadium                                   80
# Eden Gardens                                            79
# Arun Jaitley Stadium                                    78
# MA Chidambaram Stadium                                  67
# Rajiv Gandhi International Stadium                      64
# Punjab Cricket Association IS Bindra Stadium            56
# Maharashtra Cricket Association Stadium                 51
# Sawai Mansingh Stadium                                  47
# Dubai International Cricket Stadium                     46
# Dr DY Patil Sports Academy                              37
# Zayed Cricket Stadium                                   37
# Sharjah Cricket Stadium                                 28
# Brabourne Stadium                                       27
# Narendra Modi Stadium, Ahmedabad                        19
# ...

# %%
# define a function to count matches played by a team
def count_matches(team_name, df):
    # select all rows where the 'team1' or 'team2' column contains the team name
    team_matches = ipl[(ipl['team1'] == team_name) | (ipl['team2'] == team_name)]

    # count the number of rows in the resulting DataFrame to get the number of matches played by the team
    num_matches = team_matches.shape[0]

    # return the result
    return num_matches

# test the function for each team
teams = ['Rajasthan Royals', 'Royal Challengers Bangalore',
       'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
       'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
       'Punjab Kings', 'Mumbai Indians', 'Rising Pune Supergiants',
       'Kochi Tuskers Kerala']
for team in teams:
    num_matches = count_matches(team, ipl)
    print('Number of matches played by', team, ':', num_matches)
# Out:
# Number of matches played by Rajasthan Royals : 45642
# Number of matches played by Royal Challengers Bangalore : 53224
# Number of matches played by Sunrisers Hyderabad : 54408
# Number of matches played by Delhi Capitals : 52828
# Number of matches played by Chennai Super Kings : 49979
# Number of matches played by Gujarat Titans : 10989
# Number of matches played by Lucknow Super Giants : 3683
# Number of matches played by Kolkata Knight Riders : 52547
# Number of matches played by Punjab Kings : 51809
# Number of matches played by Mumbai Indians : 55680
# Number of matches played by Rising Pune Supergiants : 17923
# Number of matches played by Kochi Tuskers Kerala : 3196

# %%
ipl
# Out:
#              id       city        date season matchnumber
# 0        335982  Bengaluru  2008-04-18   2008           1  \
# 1        335982  Bengaluru  2008-04-18   2008           1
# 2        335982  Bengaluru  2008-04-18   2008           1
# 3        335982  Bengaluru  2008-04-18   2008           1
# 4        335982  Bengaluru  2008-04-18   2008           1
# ...         ...        ...         ...    ...         ...
# 225949  1312200  Ahmedabad  2022-05-29   2022       Final
# 225950  1312200  Ahmedabad  2022-05-29   2022       Final
# 225951  1312200  Ahmedabad  2022-05-29   2022       Final
# 225952  1312200  Ahmedabad  2022-05-29   2022       Final
# 225953  1312200  Ahmedabad  2022-05-29   2022       Final
#
#                               team1                  team2
# 0       Royal Challengers Bangalore  Kolkata Knight Riders  \
# 1       Royal Challengers Bangalore  Kolkata Knight Riders
# 2       Royal Challengers Bangalore  Kolkata Knight Riders
# ...
